# %% [markdown]
# <a href="https://colab.research.google.com/github/KoteswaraRaoSurimalli/ai-mentor-portfolio/blob/main/Day10_MultiAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q "numpy<2.0"
# !pip install -q --upgrade crewai litellm google-generativeai google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 82.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 976.4/976.4 kB 21.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.5/111.5 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 85.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 822.5/822.5 kB 50.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 78.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 21.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.2/178.2 kB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 20.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 19.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 110.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.6/803.6 kB 41.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 22.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.7/360.7 kB 27.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 108.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.8/334.8 kB 23.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 82.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 100.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.1/731.1 kB 44.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.5/310.5 kB 25.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.3/122.3 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 21.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.53.0 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-api>=1.35.0, but you have opentelemetry-api 1.34.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# google-adk 1.29.0 requires google-genai<2.0.0,>=1.64.0, but you have google-genai 2.7.0 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.34.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-exporter-otlp-proto-http>=1.36.0, but you have opentelemetry-exporter-otlp-proto-http 1.34.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# wandb 0.27.0 requires click>=8.2.0, but you have click 8.1.8 which is incompatible.
# bigframes 2.40.0 requires rich<14,>=12.4.4, but you have rich 14.3.4 which is incompatible.

# %% [markdown]
# Installation completes without red traceback.

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("AIzaSyCAc86A94_te_nNfiF_7aB50umG8WQS53k")

print("API key set")
# Out:
# AIzaSyCAc86A94_te_nNfiF_7aB50umG8WQS53k··········
# API key set

# %%
from crewai import Agent, Task, Crew, Process

print("CrewAI imported successfully")
# Out:
# 05:18:07 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 05:18:07 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# CrewAI imported successfully

# %% [markdown]
# CrewAI imported successfully

# %%
llm = "gemini/gemini-2.5-flash"

print(llm)
# Out:
# gemini/gemini-2.5-flash

# %%
llm = "gemini/gemini-2.5-flash"

# %%
researcher = Agent(
    role="Placement Researcher",
    goal="Compile concise, factual placement-prep notes for B.Tech students",
    backstory="You are a research analyst who prepares short factual placement briefs in bullet form.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Researcher agent created")
# Out:
# Researcher agent created

# %%
writer = Agent(
    role="Placement Brief Writer",
    goal="Convert research notes into a clean 1-page placement brief in markdown",
    backstory="You write clear student-friendly placement briefs with headings and actionable takeaways.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Writer agent created")
# Out:
# Writer agent created

# %%
research_task = Task(
    description=(
        "Research TCS Digital placement preparation for B.Tech students. "
        "Include hiring process, technical stack, eligibility, recent hiring trends, "
        "and preparation tips. Give 3-5 bullets per section."
    ),
    agent=researcher,
    expected_output=(
        "Markdown bullet list with 5 sections: Hiring Process, Technical Stack, "
        "Eligibility, Recent Hiring Trends, Prep Tips."
    ),
)

print("Research task created")
# Out:
# Research task created

# %%
write_task = Task(
    description=(
        "Using the research notes, produce a 1-page placement brief for B.Tech students. "
        "Use markdown format. Include a 3-line opening hook, 5 clear sections, "
        "and a 3-line closing call-to-action."
    ),
    agent=writer,
    expected_output='1-page markdown brief titled "TCS Digital — Placement Prep Brief".',
)

print("Writer task created")
# Out:
# Writer task created

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True,
)

print("Crew created successfully")
# Out:
# Crew created successfully

# %% [markdown]
# Agent = worker
# Task = assignment
# Crew = team
# Process = workflow style

# %%
result = await crew.kickoff_async()

print("\n\n=== FINAL OUTPUT ===\n")
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: db4b7b69-554a-4c84-bb61-46bfabca388d                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  ID: 3d890ab0-063c-47b0-8c53-67cc2cac8bbf                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here are placement preparation notes for TCS Digital for B.Tech students:                                      │
# │                                                                                                                 │
# │  ### Hiring Process                                                                                             │
# │  *   **Online Assessment:** Typically includes sections on Verbal Ability, Reasoning Ability, Numerical         │
# │  Ability, and Advanced Coding/Programming Logic. This is often conducted via TCS iON NQT (National Qualifier    │
# │  Test).                                                                                                         │
# │  *   **Technical Interview:** Focuses on Data Structures & Algorithms, programming language proficiency (Java,  │
# │  Python, C++), Database Management Systems, Operating Systems, Computer Networks, and project discussions.      │
# │  *   **Managerial Interview:** Evaluates problem-solving approach, leadership potential, ability to handle      │
# │  challenging situations, and sometimes delves deeper into project architecture or team experience.              │
# │  *   **HR Interview:** Assesses communication skills, cultural fit, career aspirations, and verifies details    │
# │  from your resume.                                                                                              │
# │                                                                                                                 │
# │  ### Technical Stack                                                                                            │
# │  *   **Core Programming:** Strong proficiency in at least one language like Java, Python, C++, or JavaScript.   │
# │  *   **Data Structures & Algorithms (DSA):** Essential for solving complex coding problems during assessments   │
# │  and interviews.                                                                                                │
# │  *   **Databases:** Understanding of SQL (MySQL, PostgreSQL) and often exposure to NoSQL databases (MongoDB,    │
# │  Cassandra).                                                                                                    │
# │  *   **Cloud Technologies:** Familiarity with concepts and services from major cloud providers like AWS,        │
# │  Azure, or GCP is highly valued.                                                                                │
# │  *   **Emerging Technologies:** Exposure to areas such as Artificial Intelligence/Machine Learning, IoT, Big    │
# │  Data, Blockchain, or Full Stack Development frameworks (e.g., Spring Boot, React, Angular).                    │
# │                                                                                                                 │
# │  ### Eligibility                                                                                                │
# │  *   **Degree:** B.E./B.Tech graduates (typically CSE, IT, ECE, EEE, EIE) are eligible.                         │
# │  *   **Academic Percentage:** Often requires a minimum of 70% or 7 CGPA throughout 10th, 12th, and B.Tech.      │
# │  *   **Backlogs:** Generally, no active backlogs are allowed at the time of applying or selection.              │
# │  *   **Academic Gap:** A maximum of 1-2 years gap in education, if any, is usually permissible with valid       │
# │  reasons.                                                                                                       │
# │                                                                                                                 │
# │  ### Recent Hiring Trends                                                                                       │
# │  *   **Focus on Advanced Skills:** Increased emphasis on candidates with demonstrated skills in niche and       │
# │  emerging technologies beyond traditional IT.                                                                   │
# │  *   **Problem-Solving Prowess:** Higher weightage given to candidates who excel in competitive programming     │
# │  and advanced DSA.                                                                                              │
# │  *   **NQT Integration:** TCS NQT (National Qualifier Test) is a primary gateway, with higher scores            │
# │  potentially leading to Digital offers.                                                                         │
# │  *   **Project-Based Evaluation:** More scrutiny on real-world projects, contributions, and technical depth in  │
# │  specific domains (e.g., AI/ML, Cloud, Data Science).                                                           │
# │  *   **Cross-Domain Expertise:** A preference for candidates who show an aptitude for learning and applying     │
# │  technologies across different domains.                                                                         │
# │                                                                                                                 │
# │  ### Prep Tips                                                                                                  │
# │  *   **Master DSA & Coding:** Dedicate significant time to Data Structures and Algorithms. Practice daily on    │
# │  platforms like LeetCode, HackerRank, and GeeksforGeeks.                                                        │
# │  *   **Choose & Excel in a Language:** Become exceptionally proficient in one programming language (Java,       │
# │  Python, C++). Understand its nuances and best practices.                                                       │
# │  *   **Build Relevant Projects:** Develop multiple hands-on projects, especially those incorporating modern     │
# │  technologies like AI/ML, Web Development frameworks, or Cloud services. Be ready to explain them thoroughly.   │
# │  *   **Strengthen CS Fundamentals:** Review core computer science subjects: Operating Systems, DBMS, Computer   │
# │  Networks, and Object-Oriented Programming (OOPs) concepts.                                                     │
# │  *   **Practice Mock Interviews & Communication:** Work on your verbal and non-verbal communication skills.     │
# │  Participate in mock technical, managerial, and HR interviews to gain confidence.                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  ID: 610772ac-7bb1-41ae-a91e-a9d349ec1191                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # TCS Digital — Placement Prep Brief                                                                           │
# │                                                                                                                 │
# │  Dreaming of a high-impact career in cutting-edge technology? TCS Digital offers an exceptional pathway for     │
# │  B.Tech graduates seeking to innovate and excel. This brief outlines what it takes to secure your spot and      │
# │  thrive in a world-class IT environment.                                                                        │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 1. The TCS Digital Hiring Journey                                                                          │
# │                                                                                                                 │
# │  TCS Digital employs a rigorous, multi-stage process designed to identify top talent. Familiarize yourself      │
# │  with each phase:                                                                                               │
# │                                                                                                                 │
# │  *   **Online Assessment (TCS iON NQT):** Your gateway! Expect sections on Verbal, Reasoning, Numerical         │
# │  Ability, and crucial Advanced Coding/Programming Logic.                                                        │
# │  *   **Technical Interview:** Deep dive into your technical prowess. Be ready for Data Structures &             │
# │  Algorithms, core programming language expertise (Java, Python, C++), DBMS, OS, Computer Networks, and          │
# │  detailed discussions on your projects.                                                                         │
# │  *   **Managerial Interview:** Beyond tech, this round assesses your problem-solving approach, leadership       │
# │  potential, ability to handle challenges, and often delves into project architecture or team experiences.       │
# │  *   **HR Interview:** A final check on communication skills, cultural fit, career aspirations, and             │
# │  verification of your resume details.                                                                           │
# │                                                                                                                 │
# │  ### 2. Key Technical Skills TCS Digital Seeks                                                                  │
# │                                                                                                                 │
# │  Build a strong foundation and demonstrate proficiency in these areas:                                          │
# │                                                                                                                 │
# │  *   **Core Programming:** Master at least one language: Java, Python, C++, or JavaScript.                      │
# │  *   **Data Structures & Algorithms (DSA):** Non-negotiable for solving complex coding challenges.              │
# │  *   **Databases:** Solid understanding of SQL (MySQL, PostgreSQL); exposure to NoSQL (MongoDB) is a plus.      │
# │  *   **Cloud Technologies:** Familiarity with AWS, Azure, or GCP concepts and services is highly valued.        │
# │  *   **Emerging Technologies:** Show awareness or hands-on experience in AI/ML, IoT, Big Data, Blockchain, or   │
# │  Full Stack Development frameworks (e.g., Spring Boot, React, Angular).                                         │
# │                                                                                                                 │
# │  ### 3. Eligibility Criteria Overview                                                                           │
# │                                                                                                                 │
# │  Ensure you meet the basic requirements to be considered:                                                       │
# │                                                                                                                 │
# │  *   **Degree:** B.E./B.Tech graduates, typically from CSE, IT, ECE, EEE, EIE branches.                         │
# │  *   **Academic Percentage:** A consistent minimum of 70% or 7 CGPA across 10th, 12th, and B.Tech.              │
# │  *   **Backlogs:** No active backlogs allowed at the time of application or selection.                          │
# │  *   **Academic Gap:** A maximum of 1-2 years gap in education might be permissible with valid reasons.         │
# │                                                                                                                 │
# │  ### 4. What TCS Digital Truly Values                                                                           │
# │                                                                                                                 │
# │  Recent trends highlight a focus on well-rounded, future-ready engineers:                                       │
# │                                                                                                                 │
# │  *   **Advanced & Niche Skills:** Demonstrated expertise beyond conventional IT, especially in emerging tech.   │
# │  *   **Superior Problem-Solving:** Excellence in competitive programming and advanced DSA.                      │
# │  *   **High NQT Scores:** Your performance in the National Qualifier Test can be a direct path to Digital       │
# │  offers.                                                                                                        │
# │  *   **Real-World Project Impact:** In-depth understanding and contribution to technically sound projects       │
# │  (AI/ML, Cloud, Data Science, etc.).                                                                            │
# │  *   **Cross-Domain Aptitude:** A proactive approach to learning and applying technologies across various       │
# │  domains.                                                                                                       │
# │                                                                                                                 │
# │  ### 5. Your Action Plan for Success                                                                            │
# │                                                                                                                 │
# │  Strategize your preparation with these actionable tips:                                                        │
# │                                                                                                                 │
# │  *   **Master DSA & Coding:** Dedicate significant daily practice using platforms like LeetCode, HackerRank,    │
# │  and GeeksforGeeks.                                                                                             │
# │  *   **Choose & Excel in a Language:** Become an expert in one programming language (Java, Python, C++) –       │
# │  understand its core and advanced features.                                                                     │
# │  *   **Build Relevant Projects:** Develop diverse, hands-on projects, ideally incorporating modern              │
# │  technologies. Be prepared to explain every technical detail.                                                   │
# │  *   **Strengthen CS Fundamentals:** Revisit core Computer Science subjects: OS, DBMS, Computer Networks, and   │
# │  Object-Oriented Programming (OOPs) concepts.                                                                   │
# │  *   **Practice Mock Interviews & Communication:** Hone your verbal and non-verbal communication. Participate   │
# │  in mock technical, managerial, and HR interviews to build confidence and refine your responses.                │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  Your journey to TCS Digital begins with focused preparation and a keen understanding of what's expected.       │
# │  Dedicate yourself, practice consistently, and showcase your best.                                              │
# │  Success isn't just about coding; it's about problem-solving, innovation, and effective communication.          │
# │  Embrace the challenge, and let your potential shine through!                                                   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === FINAL OUTPUT ===
#
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact career in cutting-edge technology? TCS Digital offers an exceptional pathway for B.Tech graduates seeking to innovate and excel. This brief outlines what it takes to secure your spot and thrive in a world-class IT environment.
#
# ---
#
# ### 1. The TCS Digital Hiring Journey
#
# TCS Digital employs a rigorous, multi-stage process designed to identify top talent. Familiarize yourself with each phase:
#
# *   **Online Assessment (TCS iON NQT):** Your gateway! Expect sections on Verbal, Reasoning, Numerical Ability, and crucial Advanced Coding/Programming Logic.
# *   **Technical Interview:** Deep dive into your technical prowess. Be ready for Data Structures & Algorithms, core programming language expertise (Java, Python, C++), DBMS, OS, Computer Networks, and detailed discussions on your projects.
# *   **Managerial Interview:** Beyond tech, this round assesses your problem-solving approach, leadership potential, ability to handle challenges, and often delves into project architecture or team experiences.
# *   **HR Interview:** A final check on communication skills, cultural fit, career aspirations, and verification of your resume details.
#
# ### 2. Key Technical Skills TCS Digital Seeks
#
# Build a strong foundation and demonstrate proficiency in these areas:
#
# *   **Core Programming:** Master at least one language: Java, Python, C++, or JavaScript.
# *   **Data Structures & Algorithms (DSA):** Non-negotiable for solving complex coding challenges.
# *   **Databases:** Solid understanding of SQL (MySQL, PostgreSQL); exposure to NoSQL (MongoDB) is a plus.
# *   **Cloud Technologies:** Familiarity with AWS, Azure, or GCP concepts and services is highly valued.
# *   **Emerging Technologies:** Show awareness or hands-on experience in AI/ML, IoT, Big Data, Blockchain, or Full Stack Development frameworks (e.g., Spring Boot, React, Angular).
#
# ### 3. Eligibility Criteria Overview
#
# Ensure you meet the basic requirements to be considered:
#
# *   **Degree:** B.E./B.Tech graduates, typically from CSE, IT, ECE, EEE, EIE branches.
# *   **Academic Percentage:** A consistent minimum of 70% or 7 CGPA across 10th, 12th, and B.Tech.
# *   **Backlogs:** No active backlogs allowed at the time of application or selection.
# *   **Academic Gap:** A maximum of 1-2 years gap in education might be permissible with valid reasons.
#
# ### 4. What TCS Digital Truly Values
#
# Recent trends highlight a focus on well-rounded, future-ready engineers:
#
# *   **Advanced & Niche Skills:** Demonstrated expertise beyond conventional IT, especially in emerging tech.
# *   **Superior Problem-Solving:** Excellence in competitive programming and advanced DSA.
# *   **High NQT Scores:** Your performance in the National Qualifier Test can be a direct path to Digital offers.
# *   **Real-World Project Impact:** In-depth understanding and contribution to technically sound projects (AI/ML, Cloud, Data Science, etc.).
# *   **Cross-Domain Aptitude:** A proactive approach to learning and applying technologies across various domains.
#
# ### 5. Your Action Plan for Success
#
# Strategize your preparation with these actionable tips:
#
# *   **Master DSA & Coding:** Dedicate significant daily practice using platforms like LeetCode, HackerRank, and GeeksforGeeks.
# *   **Choose & Excel in a Language:** Become an expert in one programming language (Java, Python, C++) – understand its core and advanced features.
# *   **Build Relevant Projects:** Develop diverse, hands-on projects, ideally incorporating modern technologies. Be prepared to explain every technical detail.
# *   **Strengthen CS Fundamentals:** Revisit core Computer Science subjects: OS, DBMS, Computer Networks, and Object-Oriented Programming (OOPs) concepts.
# *   **Practice Mock Interviews & Communication:** Hone your verbal and non-verbal communication. Participate in mock technical, managerial, and HR interviews to build confidence and refine your responses.
#
# ---
#
# Your journey to TCS Digital begins with focused preparation and a keen understanding of what's expected. Dedicate yourself, practice consistently, and showcase your best.
# Success isn't just about coding; it's about problem-solving, innovation, and effective communication.
# Embrace the challenge, and let your potential shine through!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────── Tracing Preference Saved ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing has been disabled.                                                                               │
# │                                                                                                                 │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                           │
# │                                                                                                                 │
# │  To enable tracing later, do any one of these:                                                                  │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
import pathlib

pathlib.Path("day10_lab10a_transcript.txt").write_text(str(result))

print("Saved: day10_lab10a_transcript.txt")
print("Characters:", len(str(result)))
# Out:
# Saved: day10_lab10a_transcript.txt
# Characters: 4280

# %%
try:
    for i, output in enumerate(result.tasks_output):
        print(f"\n=== Task {i+1} Output ===")
        print(str(output)[:800])
except Exception:
    print("Task outputs not available in this CrewAI version.")
    print("Final result saved successfully.")
# Out:
# === Task 1 Output ===
# Here are placement preparation notes for TCS Digital for B.Tech students:
#
# ### Hiring Process
# *   **Online Assessment:** Typically includes sections on Verbal Ability, Reasoning Ability, Numerical Ability, and Advanced Coding/Programming Logic. This is often conducted via TCS iON NQT (National Qualifier Test).
# *   **Technical Interview:** Focuses on Data Structures & Algorithms, programming language proficiency (Java, Python, C++), Database Management Systems, Operating Systems, Computer Networks, and project discussions.
# *   **Managerial Interview:** Evaluates problem-solving approach, leadership potential, ability to handle challenging situations, and sometimes delves deeper into project architecture or team experience.
# *   **HR Interview:** Assesses communication skills, cultural fit, c
#
# === Task 2 Output ===
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact career in cutting-edge technology? TCS Digital offers an exceptional pathway for B.Tech graduates seeking to innovate and excel. This brief outlines what it takes to secure your spot and thrive in a world-class IT environment.
#
# ---
#
# ### 1. The TCS Digital Hiring Journey
#
# TCS Digital employs a rigorous, multi-stage process designed to identify top talent. Familiarize yourself with each phase:
#
# *   **Online Assessment (TCS iON NQT):** Your gateway! Expect sections on Verbal, Reasoning, Numerical Ability, and crucial Advanced Coding/Programming Logic.
# *   **Technical Interview:** Deep dive into your technical prowess. Be ready for Data Structures & Algorithms, core programming language expertise (Java, Python, C++), DBMS, OS, Com

# %%
markdown_content = str(result)

with open("tcs_digital_brief.md", "w", encoding="utf-8") as f:
    f.write(markdown_content)

print("Markdown file created successfully: tcs_digital_brief.md")
# Out:
# Markdown file created successfully: tcs_digital_brief.md

# %%
from google.colab import files

files.download("tcs_digital_brief.md")

# %%
with open("tcs_digital_brief.md", "r", encoding="utf-8") as f:
    print(f.read()[:2000])
# Out:
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact career in cutting-edge technology? TCS Digital offers an exceptional pathway for B.Tech graduates seeking to innovate and excel. This brief outlines what it takes to secure your spot and thrive in a world-class IT environment.
#
# ---
#
# ### 1. The TCS Digital Hiring Journey
#
# TCS Digital employs a rigorous, multi-stage process designed to identify top talent. Familiarize yourself with each phase:
#
# *   **Online Assessment (TCS iON NQT):** Your gateway! Expect sections on Verbal, Reasoning, Numerical Ability, and crucial Advanced Coding/Programming Logic.
# *   **Technical Interview:** Deep dive into your technical prowess. Be ready for Data Structures & Algorithms, core programming language expertise (Java, Python, C++), DBMS, OS, Computer Networks, and detailed discussions on your projects.
# *   **Managerial Interview:** Beyond tech, this round assesses your problem-solving approach, leadership potential, ability to handle challenges, and often delves into project architecture or team experiences.
# *   **HR Interview:** A final check on communication skills, cultural fit, career aspirations, and verification of your resume details.
#
# ### 2. Key Technical Skills TCS Digital Seeks
#
# Build a strong foundation and demonstrate proficiency in these areas:
#
# *   **Core Programming:** Master at least one language: Java, Python, C++, or JavaScript.
# *   **Data Structures & Algorithms (DSA):** Non-negotiable for solving complex coding challenges.
# *   **Databases:** Solid understanding of SQL (MySQL, PostgreSQL); exposure to NoSQL (MongoDB) is a plus.
# *   **Cloud Technologies:** Familiarity with AWS, Azure, or GCP concepts and services is highly valued.
# *   **Emerging Technologies:** Show awareness or hands-on experience in AI/ML, IoT, Big Data, Blockchain, or Full Stack Development frameworks (e.g., Spring Boot, React, Angular).
#
# ### 3. Eligibility Criteria Overview
#
# Ensure you meet the basic requirements to be considered:
#
# *
