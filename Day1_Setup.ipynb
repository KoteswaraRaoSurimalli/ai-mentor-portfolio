# %% [markdown]
# <a href="https://colab.research.google.com/github/KoteswaraRaoSurimalli/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hiiii")
# Out:
# Hiiii

# %%
pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain About Ramayana'
)
print(resp.text)
# Out:
# The **Ramayana** (meaning "Rama's Journey") is one of the two major Sanskrit epics of ancient India, the other being the Mahabharata. It is attributed to the Hindu sage **Valmiki**, who is considered the Adi Kavi (first poet). It's a foundational text in Hinduism and has profoundly influenced the art, culture, and traditions of India and Southeast Asia.
#
# At its heart, the Ramayana is a narrative about **Dharma** (righteous conduct), duty, sacrifice, and the eternal struggle between good and evil.
#
# ## Key Elements of the Ramayana:
#
# 1.  **Divine Origin & Protagonist:**
#     *   The central figure is **Lord Rama**, who is an avatar (incarnation) of the Hindu god Vishnu, descended to Earth to eradicate evil and establish righteousness.
#     *   He is depicted as the ideal son, brother, husband, friend, and king, embodying all virtues.
#
# 2.  **Major Characters:**
#     *   **Lord Rama:** Prince of Ayodhya, eldest son of King Dasharatha. The embodiment of Dharma.
# ...
